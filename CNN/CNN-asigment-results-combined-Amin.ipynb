# %% [markdown]
# # Deep Learning

# %% [markdown]
# # Assignment 2 -CNN

# %% [markdown]
# ### Submitted by:
# #### Name      : Muhammad Amin Ghias
# #### ERP ID    : 25366

# %% [markdown]
# Date : 26th November 2022

# %% [markdown]
# # Overall Reults analysis of CNN of all datasets

# %%
import pandas as pd

# %% [markdown]
# # Dataset 1 - Grape wine leaves

# %%
dfr1=pd.read_csv('df_results1.csv')

dfr1
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 0                 relu              64      max     100       0.859023
# 1                  elu              64      max     100       0.919173
# 2                 gelu              64      max     100       0.860902
# 3                 selu              64      max     100       0.810150
# 4            LeakyReLU              64      max     100       0.866541
# 5                 relu              64  average     100       0.665414
# 6                  elu              64  average     100       0.859023
# 7                 gelu              64  average     100       0.394737
# 8                 selu              64  average     100       0.757519
# 9            LeakyReLU              64  average     100       0.473684
# 10                 elu              16      max     100       0.609023
# 11                 elu              32      max     100       0.667293
# ...

# %% [markdown]
# #### datset has 2660 images
#
# #### training done on 2128 imges of dimensions 64x64  (2128, 64, 64, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -1

# %%
dfr1_p_avg = dfr1.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr1_p_avg.head()
# Out:
#          number_filters  epochs  test_accuracy
# pooling
# max           62.222222   100.0       0.813701
# average       64.000000   100.0       0.630075

# %%
dfr1_act_avg = dfr1.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr1_act_avg.head()
# Out:
#                      number_filters  epochs  test_accuracy
# activation_function
# elu                       61.333333   100.0       0.797619
# selu                      64.000000   100.0       0.783835
# relu                      64.000000   100.0       0.762218
# LeakyReLU                 64.000000   100.0       0.670113
# gelu                      64.000000   100.0       0.627820

# %%
dfr1_filt_avg = dfr1.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr1_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 128                100       0.857143
# 64                 100       0.758202
# 32                 100       0.667293
# 16                 100       0.609023

# %% [markdown]
# ### Based on average results for dataset 1 'elu' , 'max-pooling' and '128' filters give best result accuarcy

# %%
df_avg=pd.DataFrame(columns=['activation_function', 'pooling', 'epochs', 'number_filters', 'dataset'])

df_avg
# Out:
# Empty DataFrame
# Columns: [activation_function, pooling, epochs, number_filters, dataset]
# Index: []

# %%
df_max=pd.DataFrame(columns=['activation_function', 'pooling', 'epochs','number_filters', 'dataset'])

df_max
# Out:
# Empty DataFrame
# Columns: [activation_function, pooling, epochs, number_filters, dataset]
# Index: []

# %%
df_avg=df_avg.append({'activation_function': 'elu' , 'pooling': 'max', 'epochs': 100, 
                       'dataset':'Grapevine Leaves Image Dataset','number_filters': 128 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
#
#                           dataset
# 0  Grapevine Leaves Image Dataset

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -1

# %%
dfr1_p_max = dfr1.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr1_p_max.head()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# max                    selu             128     100       0.919173
# average                selu              64     100       0.859023
#
#                                 dataset
# pooling
# max      Grapevine Leaves Image Dataset
# average  Grapevine Leaves Image Dataset

# %%
dfr1.groupby('pooling').max()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# average                selu              64     100       0.859023
# max                    selu             128     100       0.919173
#
#                                 dataset
# pooling
# average  Grapevine Leaves Image Dataset
# max      Grapevine Leaves Image Dataset

# %%
dfr1_act_max = dfr1.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr1_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# elu                             128     max     100       0.919173
# LeakyReLU                        64     max     100       0.866541
# gelu                             64     max     100       0.860902
# relu                             64     max     100       0.859023
# selu                             64     max     100       0.810150
#
#                                             dataset
# activation_function
# elu                  Grapevine Leaves Image Dataset
# LeakyReLU            Grapevine Leaves Image Dataset
# gelu                 Grapevine Leaves Image Dataset
# relu                 Grapevine Leaves Image Dataset
# selu                 Grapevine Leaves Image Dataset

# %%
dfr1_filt_max = dfr1.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr1_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max     100       0.919173
# 128                            elu     max     100       0.857143
# 32                             elu     max     100       0.667293
# 16                             elu     max     100       0.609023
#
#                                        dataset
# number_filters
# 64              Grapevine Leaves Image Dataset
# 128             Grapevine Leaves Image Dataset
# 32              Grapevine Leaves Image Dataset
# 16              Grapevine Leaves Image Dataset

# %% [markdown]
# ### Based on max results for dataset 1 'elu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'elu' , 'pooling': 'max', 'epochs': 100, 
                       'dataset':'Grapevine Leaves Image Dataset','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100             64
#
#                           dataset
# 0  Grapevine Leaves Image Dataset

# %% [markdown]
# ### Final conculsion for dataset 1 is the 'elu' with 'max-pooling' and filters 128 will give better results

# %%
df_final=pd.DataFrame(columns=['activation_function', 'pooling', 'epochs', 'number_filters', 'dataset'])

df_final
# Out:
# Empty DataFrame
# Columns: [activation_function, pooling, epochs, number_filters, dataset]
# Index: []

# %%
df_final=df_final.append({'activation_function': 'elu' , 'pooling': 'max', 'epochs': 100, 
                       'dataset':'Grapevine Leaves Image Dataset','number_filters': 128 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
#
#                           dataset
# 0  Grapevine Leaves Image Dataset

# %%
df_imagenet=pd.DataFrame(columns=['model_name','epochs','test_accuracy','dataset'])
df_imagenet
# Out:
# Empty DataFrame
# Columns: [model_name, epochs, test_accuracy, dataset]
# Index: []

# %% [markdown]
# ## Imagenet winner models-dataset 1

# %%
# Resnet

dataset='Grapevine Leaves Image Dataset'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.964285 ,
                                'dataset': dataset,'epochs':100 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.802631 ,
                                'dataset': dataset,'epochs':100 },ignore_index=True)


df_imagenet
# Out:
#      model_name epochs  test_accuracy                         dataset
# 0        ResNet    100       0.964285  Grapevine Leaves Image Dataset
# 1  Inception_V3    100       0.802631  Grapevine Leaves Image Dataset

# %% [markdown]
# # Dataset 2 - Traffic Sign Dataset - Classification

# %%
dfr2=pd.read_csv('df_results1_d2.csv')

dfr2.sort_values('test_accuracy',ascending = False)
# Out:
#    activation_function  number_filters                  pooling  epochs  \
# 0                 selu              64                      max      25
# 4                 gelu              64  <built-in function max>      25
# 12                gelu              64                      max      25
# 3                  elu              64  <built-in function max>      25
# 7                 gelu              64                  average      25
# 1            LeakyReLU              64                      max      25
# 11                gelu              32                      max      25
# 2                 relu              64  <built-in function max>      25
# 6                  elu              64                  average      25
# 8                 selu              64                  average      25
# 9            LeakyReLU              64                  average      25
# 10                gelu              16                      max      25
# ...

# %% [markdown]
# #### dataset has 4170 images
#
# #### training done on 3336 imges of dimensions 128x128  (3336, 128, 128, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -2

# %%
dfr2_p_avg = dfr2.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr2_p_avg.head()
# Out:
#                          number_filters  epochs  test_accuracy
# pooling
# <built-in function max>              64      25       0.810951
# max                                  48      25       0.800000
# average                              64      25       0.762590

# %%
dfr2_act_avg = dfr2.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr2_act_avg.head()
# Out:
#                      number_filters  epochs  test_accuracy
# activation_function
# selu                             64      25       0.819544
# gelu                             48      25       0.797122
# elu                              64      25       0.791367
# LeakyReLU                        64      25       0.766187
# relu                             64      25       0.752997

# %%
dfr2_filt_avg = dfr2.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr2_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 64                  25       0.793329
# 32                  25       0.776978
# 16                  25       0.742206

# %% [markdown]
# ### Based on average results for dataset 2 'selu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_avg=df_avg.append({'activation_function': 'selu' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Traffic Sign Dataset - Classification','number_filters': 64 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -2

# %%
dfr2_p_max = dfr2.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr2_p_max.head()
# Out:
#                         activation_function  number_filters  epochs  \
# pooling
# max                                    selu              64      25
# <built-in function max>                relu              64      25
# average                                selu              64      25
#
#                          test_accuracy                                dataset
# pooling
# max                           0.870504  Traffic Sign Dataset - Classification
# <built-in function max>       0.845323  Traffic Sign Dataset - Classification
# average                       0.799760  Traffic Sign Dataset - Classification

# %%
dfr2_act_max = dfr2.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr2_act_max.head()
# Out:
#                      number_filters  pooling  epochs  test_accuracy  \
# activation_function
# selu                             64      max      25       0.870504
# gelu                             64      max      25       0.845323
# elu                              64  average      25       0.812949
# LeakyReLU                        64      max      25       0.788969
# relu                             64  average      25       0.774580
#
#                                                    dataset
# activation_function
# selu                 Traffic Sign Dataset - Classification
# gelu                 Traffic Sign Dataset - Classification
# elu                  Traffic Sign Dataset - Classification
# LeakyReLU            Traffic Sign Dataset - Classification
# relu                 Traffic Sign Dataset - Classification

# %%
dfr2_filt_max = dfr2.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr2_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max      25       0.870504
# 32                            gelu     max      25       0.776978
# 16                            gelu     max      25       0.742206
#
#                                               dataset
# number_filters
# 64              Traffic Sign Dataset - Classification
# 32              Traffic Sign Dataset - Classification
# 16              Traffic Sign Dataset - Classification

# %% [markdown]
# ### Based on max results for dataset 2 'selu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'selu' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Traffic Sign Dataset - Classification','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100             64
# 1                selu     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification

# %% [markdown]
# ### Final conculsion for dataset 2 is the 'selu' with 'max-pooling' and filters 64 will give better results

# %%
df_final=df_final.append({'activation_function': 'selu' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Traffic Sign Dataset - Classification','number_filters': 64 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification

# %% [markdown]
# ## Imagenet winner models-dataset 2

# %%
# Resnet

dataset='Traffic Sign Dataset - Classification'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.956834 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.928057 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'VGG', 'test_accuracy': 0.109112 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)


df_imagenet
# Out:
#      model_name epochs  test_accuracy                                dataset
# 0        ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1  Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2        ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3  Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4           VGG     25       0.109112  Traffic Sign Dataset - Classification

# %% [markdown]
# # Dataset 3 - FaceMask Dataset

# %%
dfr3=pd.read_csv('df_results1_d3.csv')

dfr3.sort_values('test_accuracy',ascending = False)
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 1                 relu              64      max      25       0.981884
# 7                  elu              64  average      25       0.981884
# 12                relu              32      max      25       0.978261
# 0                 relu              62      max      30       0.974638
# 5            LeakyReLU              64      max      25       0.974638
# 14                relu             128      max      25       0.974638
# 8                 gelu              64  average      25       0.971014
# 3                 gelu              64      max      25       0.963768
# 9                 selu              64  average      25       0.963768
# 4                 selu              64      max      25       0.960145
# 13                relu              64      max      25       0.956522
# 6                 relu              64  average      25       0.952899
# ...

# %% [markdown]
# #### dataset has 1376 images
#
# #### training done on 1100 imges of dimensions 128x128  (1100, 128, 128, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -3

# %%
dfr3_p_avg = dfr3.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr3_p_avg.head()
# Out:
#          number_filters  epochs  test_accuracy
# pooling
# max                62.2    25.5       0.964855
# average            64.0    25.0       0.958696

# %%
dfr3_act_avg = dfr3.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr3_act_avg.head()
# Out:
#                      number_filters     epochs  test_accuracy
# activation_function
# gelu                      64.000000  25.000000       0.967391
# relu                      61.428571  25.714286       0.966356
# selu                      64.000000  25.000000       0.961957
# elu                       64.000000  25.000000       0.960145
# LeakyReLU                 64.000000  25.000000       0.949275

# %%
dfr3_filt_avg = dfr3.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr3_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 32                  25       0.978261
# 62                  30       0.974638
# 128                 25       0.974638
# 64                  25       0.960804
# 16                  25       0.945652

# %% [markdown]
# ### Based on average results for dataset 3 'gelu' , 'max-pooling' and '32' filters give best result accuarcy

# %%
df_avg=df_avg.append({'activation_function': 'gelu' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'FaceMask Dataset','number_filters': 32 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -3

# %%
dfr3_p_max = dfr3.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr3_p_max.head()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# average                selu              64      25       0.981884
# max                    selu             128      30       0.981884
#
#                   dataset
# pooling
# average  FaceMask Dataset
# max      FaceMask Dataset

# %%
dfr3_act_max = dfr3.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr3_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# elu                              64     max      25       0.981884
# relu                            128     max      30       0.981884
# LeakyReLU                        64     max      25       0.974638
# gelu                             64     max      25       0.971014
# selu                             64     max      25       0.963768
#
#                               dataset
# activation_function
# elu                  FaceMask Dataset
# relu                 FaceMask Dataset
# LeakyReLU            FaceMask Dataset
# gelu                 FaceMask Dataset
# selu                 FaceMask Dataset

# %%
dfr3_filt_max = dfr3.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr3_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max      25       0.981884
# 32                            relu     max      25       0.978261
# 62                            relu     max      30       0.974638
# 128                           relu     max      25       0.974638
# 16                            relu     max      25       0.945652
#
#                          dataset
# number_filters
# 64              FaceMask Dataset
# 32              FaceMask Dataset
# 62              FaceMask Dataset
# 128             FaceMask Dataset
# 16              FaceMask Dataset

# %% [markdown]
# ### Based on max results for dataset 3 'elu' , 'average-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'elu' , 'pooling': 'average', 'epochs': 25, 
                       'dataset':'FaceMask Dataset','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function  pooling epochs number_filters  \
# 0                 elu      max    100             64
# 1                selu      max     25             64
# 2                 elu  average     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset

# %% [markdown]
# ### Final conculsion for dataset 3 is that 'gelu' with 'max-pooling' and filters 32 will give better results as 0.98 accuracy may lead to some overfitting

# %%
df_final=df_final.append({'activation_function': 'gelu' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'FaceMask Dataset','number_filters': 32 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset

# %% [markdown]
# ## Imagenet winner models-dataset 3

# %%
# Resnet

dataset='FaceMask Dataset'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.5 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.996376 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'VGG', 'test_accuracy': 0.5 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)


df_imagenet
# Out:
#      model_name epochs  test_accuracy                                dataset
# 0        ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1  Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2        ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3  Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4           VGG     25       0.109112  Traffic Sign Dataset - Classification
# 5        ResNet     25       0.500000                       FaceMask Dataset
# 6  Inception_V3     25       0.996376                       FaceMask Dataset
# 7           VGG     25       0.500000                       FaceMask Dataset

# %% [markdown]
# # Dataset 4 - Brain Tumor Classification

# %%
dfr4=pd.read_csv('df_results1_d4.csv')

dfr4.sort_values('test_accuracy',ascending = False)
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 5            LeakyReLU              64      max      25       0.820557
# 8                 gelu              64  average      25       0.703833
# 2                  elu              64      max      25       0.693380
# 1                 relu              64      max      25       0.670732
# 13                 elu              64      max      25       0.656794
# 0                 relu              62      max      30       0.655052
# 4                 selu              64      max      25       0.634146
# 12                 elu              32      max      25       0.618467
# 7                  elu              64  average      25       0.609756
# 3                 gelu              64      max      25       0.534843
# 11                 elu              16      max      25       0.439024
# 10           LeakyReLU              64  average      25       0.430314
# ...

# %% [markdown]
# #### dataset has 2870 images
#
# #### training done on 2296 imges of dimensions 128x128  (2296, 128, 128, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -4

# %%
dfr4_p_avg = dfr4.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr4_p_avg.head()
# Out:
#          number_filters  epochs  test_accuracy
# pooling
# max                62.2    25.5       0.610627
# average            64.0    25.0       0.482927

# %%
dfr4_act_avg = dfr4.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr4_act_avg.head()
# Out:
#                      number_filters     epochs  test_accuracy
# activation_function
# LeakyReLU                 64.000000  25.000000       0.625436
# gelu                      64.000000  25.000000       0.619338
# elu                       61.333333  25.000000       0.566783
# relu                      63.333333  26.666667       0.532520
# selu                      64.000000  25.000000       0.516551

# %%
dfr4_filt_avg = dfr4.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr4_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 62                  30       0.655052
# 32                  25       0.618467
# 64                  25       0.584099
# 16                  25       0.439024
# 128                 25       0.383275

# %% [markdown]
# ### Based on average results for dataset 4 'LeakyReLU' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_avg=df_avg.append({'activation_function': 'LeakyReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Brain Tumor Classification','number_filters': 64 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -4

# %%
dfr4_p_max = dfr4.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr4_p_max.head()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# max                    selu             128      30       0.820557
# average                selu              64      25       0.703833
#
#                             dataset
# pooling
# max      Brain Tumor Classification
# average  Brain Tumor Classification

# %%
dfr4_act_max = dfr4.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr4_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# LeakyReLU                        64     max      25       0.820557
# gelu                             64     max      25       0.703833
# elu                             128     max      25       0.693380
# relu                             64     max      30       0.670732
# selu                             64     max      25       0.634146
#
#                                         dataset
# activation_function
# LeakyReLU            Brain Tumor Classification
# gelu                 Brain Tumor Classification
# elu                  Brain Tumor Classification
# relu                 Brain Tumor Classification
# selu                 Brain Tumor Classification

# %%
dfr4_filt_max = dfr4.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr4_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max      25       0.820557
# 62                            relu     max      30       0.655052
# 32                             elu     max      25       0.618467
# 16                             elu     max      25       0.439024
# 128                            elu     max      25       0.383275
#
#                                    dataset
# number_filters
# 64              Brain Tumor Classification
# 62              Brain Tumor Classification
# 32              Brain Tumor Classification
# 16              Brain Tumor Classification
# 128             Brain Tumor Classification

# %% [markdown]
# ### Based on max results for dataset 4 'LeakyRelu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'LeakyReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Brain Tumor Classification','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function  pooling epochs number_filters  \
# 0                 elu      max    100             64
# 1                selu      max     25             64
# 2                 elu  average     25             64
# 3           LeakyReLU      max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification

# %% [markdown]
# ### Final conculsion for dataset 4 is that 'LeakyRelu' with 'max-pooling' and filters 64 will give better results

# %%
df_final=df_final.append({'activation_function': 'LeakyReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Brain Tumor Classification','number_filters': 64 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification

# %% [markdown]
# ## Imagenet winner models-dataset 4

# %%
# Resnet

dataset='Brain Tumor Classification'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.313588 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.804878 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'VGG', 'test_accuracy': 0.313588 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)


df_imagenet
# Out:
#       model_name epochs  test_accuracy                                dataset
# 0         ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1   Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2         ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3   Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4            VGG     25       0.109112  Traffic Sign Dataset - Classification
# 5         ResNet     25       0.500000                       FaceMask Dataset
# 6   Inception_V3     25       0.996376                       FaceMask Dataset
# 7            VGG     25       0.500000                       FaceMask Dataset
# 8         ResNet     25       0.313588             Brain Tumor Classification
# 9   Inception_V3     25       0.804878             Brain Tumor Classification
# 10           VGG     25       0.313588             Brain Tumor Classification

# %% [markdown]
# # Dataset 5 - Watch Image Dataset

# %%
dfr5=pd.read_csv('df_results1_d5.csv')

dfr5.sort_values('test_accuracy',ascending = False)
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 0                 relu              62      max      30         0.3325
# 5            LeakyReLU              64      max      25         0.3250
# 2                  elu              64      max      25         0.3225
# 1                 relu              64      max      25         0.3200
# 6                 relu              64  average      25         0.2975
# 4                 selu              64      max      25         0.2850
# 3                 gelu              64      max      25         0.2625
# 12                relu              32      max      25         0.2625
# 9                 selu              64  average      25         0.2225
# 7                  elu              64  average      25         0.1950
# 13                relu              64      max      25         0.1950
# 8                 gelu              64  average      25         0.1875
# ...

# %% [markdown]
# #### dataset has 2000 images
#
# #### training done on 1600 imges of dimensions 128x128  (1600, 128, 128, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -5

# %%
dfr5_p_avg = dfr5.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr5_p_avg.head()
# Out:
#          number_filters  epochs  test_accuracy
# pooling
# max                62.2    25.5         0.2665
# average            64.0    25.0         0.2110

# %%
dfr5_act_avg = dfr5.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr5_act_avg.head()
# Out:
#                      number_filters     epochs  test_accuracy
# activation_function
# elu                       64.000000  25.000000        0.25875
# selu                      64.000000  25.000000        0.25375
# relu                      61.428571  25.714286        0.25250
# LeakyReLU                 64.000000  25.000000        0.23875
# gelu                      64.000000  25.000000        0.22500

# %%
dfr5_filt_avg = dfr5.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr5_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 62                  30       0.332500
# 32                  25       0.262500
# 64                  25       0.251364
# 128                 25       0.182500
# 16                  25       0.177500

# %% [markdown]
# ### Based on average results for dataset 5 'eLU' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_avg=df_avg.append({'activation_function': 'eLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Watche Image Dataset','number_filters': 64 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -5

# %%
dfr5_p_max = dfr5.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr5_p_max.head()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# max                    selu             128      30         0.3325
# average                selu              64      25         0.2975
#
#                       dataset
# pooling
# max      Watche Image Dataset
# average  Watche Image Dataset

# %%
dfr5_act_max = dfr5.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr5_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# relu                            128     max      30         0.3325
# LeakyReLU                        64     max      25         0.3250
# elu                              64     max      25         0.3225
# selu                             64     max      25         0.2850
# gelu                             64     max      25         0.2625
#
#                                   dataset
# activation_function
# relu                 Watche Image Dataset
# LeakyReLU            Watche Image Dataset
# elu                  Watche Image Dataset
# selu                 Watche Image Dataset
# gelu                 Watche Image Dataset

# %%
dfr5_filt_max = dfr5.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr5_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 62                            relu     max      30         0.3325
# 64                            selu     max      25         0.3250
# 32                            relu     max      25         0.2625
# 128                           relu     max      25         0.1825
# 16                            relu     max      25         0.1775
#
#                              dataset
# number_filters
# 62              Watche Image Dataset
# 64              Watche Image Dataset
# 32              Watche Image Dataset
# 128             Watche Image Dataset
# 16              Watche Image Dataset

# %% [markdown]
# ### Based on max results for dataset 5 'Relu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'ReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Watche Image Dataset','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function  pooling epochs number_filters  \
# 0                 elu      max    100             64
# 1                selu      max     25             64
# 2                 elu  average     25             64
# 3           LeakyReLU      max     25             64
# 4                ReLU      max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset

# %% [markdown]
# ### Final conculsion for dataset 5 is that 'elu' with 'max-pooling' and filters 64 will give better results

# %%
df_final=df_final.append({'activation_function': 'eLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'Watche Image Dataset','number_filters': 64 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset

# %% [markdown]
# ## Imagenet winner models-dataset 5

# %%
# Resnet

dataset='Watche Image Dataset'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.11999 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.487500 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'VGG', 'test_accuracy': 0.109999 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)


df_imagenet
# Out:
#       model_name epochs  test_accuracy                                dataset
# 0         ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1   Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2         ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3   Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4            VGG     25       0.109112  Traffic Sign Dataset - Classification
# 5         ResNet     25       0.500000                       FaceMask Dataset
# 6   Inception_V3     25       0.996376                       FaceMask Dataset
# 7            VGG     25       0.500000                       FaceMask Dataset
# 8         ResNet     25       0.313588             Brain Tumor Classification
# 9   Inception_V3     25       0.804878             Brain Tumor Classification
# 10           VGG     25       0.313588             Brain Tumor Classification
# ...

# %% [markdown]
# # Dataset 6 - cars_wagonr_swift

# %%
dfr6=pd.read_csv('df_results1_d6.csv')

dfr6.sort_values('test_accuracy',ascending = False)
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 13                relu              64      max      25       0.793750
# 0                 relu              62      max      30       0.791667
# 2                  elu              64      max      25       0.764583
# 14                relu             128      max      25       0.764583
# 4                 selu              64      max      25       0.762500
# 6                 relu              64  average      25       0.752083
# 12                relu              32      max      25       0.745833
# 1                 relu              64      max      25       0.722917
# 11                relu              16      max      25       0.722917
# 5            LeakyReLU              64      max      25       0.710417
# 8                 gelu              64  average      25       0.679167
# 7                  elu              64  average      25       0.656250
# ...

# %% [markdown]
# #### dataset has 2400 images
#
# #### training done on 1920 imges of dimensions 128x128  (1920, 128, 128, 3) while rest images are for testing

# %% [markdown]
# ## Average based result - analysis of dataset -6

# %%
dfr6_p_avg = dfr6.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr6_p_avg.head()
# Out:
#          number_filters  epochs  test_accuracy
# pooling
# max                62.2    25.5       0.743125
# average            64.0    25.0       0.670000

# %%
dfr6_act_avg = dfr6.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr6_act_avg.head()
# Out:
#                      number_filters     epochs  test_accuracy
# activation_function
# relu                      61.428571  25.714286       0.756250
# elu                       64.000000  25.000000       0.710417
# selu                      64.000000  25.000000       0.690625
# LeakyReLU                 64.000000  25.000000       0.677083
# gelu                      64.000000  25.000000       0.665625

# %%
dfr6_filt_avg = dfr6.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr6_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 62                  30       0.791667
# 128                 25       0.764583
# 32                  25       0.745833
# 16                  25       0.722917
# 64                  25       0.705114

# %% [markdown]
# ### Based on average results for dataset 6 'relu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_avg=df_avg.append({'activation_function': 'ReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'cars_wagonr_swift','number_filters': 64 },ignore_index=True)

df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
# 5                ReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ## Maximun (best) based result - analysis of dataset -6

# %%
dfr6_p_max = dfr6.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr6_p_max.head()
# Out:
#         activation_function  number_filters  epochs  test_accuracy  \
# pooling
# max                    selu             128      30       0.793750
# average                selu              64      25       0.752083
#
#                    dataset
# pooling
# max      cars_wagonr_swift
# average  cars_wagonr_swift

# %%
dfr6_act_max = dfr6.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr6_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# relu                            128     max      30       0.793750
# elu                              64     max      25       0.764583
# selu                             64     max      25       0.762500
# LeakyReLU                        64     max      25       0.710417
# gelu                             64     max      25       0.679167
#
#                                dataset
# activation_function
# relu                 cars_wagonr_swift
# elu                  cars_wagonr_swift
# selu                 cars_wagonr_swift
# LeakyReLU            cars_wagonr_swift
# gelu                 cars_wagonr_swift

# %%
dfr6_filt_max = dfr6.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr6_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max      25       0.793750
# 62                            relu     max      30       0.791667
# 128                           relu     max      25       0.764583
# 32                            relu     max      25       0.745833
# 16                            relu     max      25       0.722917
#
#                           dataset
# number_filters
# 64              cars_wagonr_swift
# 62              cars_wagonr_swift
# 128             cars_wagonr_swift
# 32              cars_wagonr_swift
# 16              cars_wagonr_swift

# %% [markdown]
# ### Based on max results for dataset 6 'Relu' , 'max-pooling' and '64' filters give best result accuarcy

# %%
df_max=df_max.append({'activation_function': 'ReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'cars_wagonr_swift','number_filters': 64 },ignore_index=True)

df_max
# Out:
#   activation_function  pooling epochs number_filters  \
# 0                 elu      max    100             64
# 1                selu      max     25             64
# 2                 elu  average     25             64
# 3           LeakyReLU      max     25             64
# 4                ReLU      max     25             64
# 5                ReLU      max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ### Final conculsion for dataset 6 is that 'relu' with 'max-pooling' and filters 64 will give better results

# %%
df_final=df_final.append({'activation_function': 'ReLU' , 'pooling': 'max', 'epochs': 25, 
                       'dataset':'cars_wagonr_swift','number_filters': 64 },ignore_index=True)

df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
# 5                ReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ## Imagenet winner models-dataset 6

# %%
# Resnet

dataset='cars_wagonr_swift'

df_imagenet=df_imagenet.append({'model_name':'ResNet', 'test_accuracy': 0.516666 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'Inception_V3', 'test_accuracy': 0.858333 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)

df_imagenet=df_imagenet.append({'model_name':'VGG', 'test_accuracy': 0.516666 ,
                                'dataset': dataset,'epochs':25 },ignore_index=True)


df_imagenet
# Out:
#       model_name epochs  test_accuracy                                dataset
# 0         ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1   Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2         ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3   Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4            VGG     25       0.109112  Traffic Sign Dataset - Classification
# 5         ResNet     25       0.500000                       FaceMask Dataset
# 6   Inception_V3     25       0.996376                       FaceMask Dataset
# 7            VGG     25       0.500000                       FaceMask Dataset
# 8         ResNet     25       0.313588             Brain Tumor Classification
# 9   Inception_V3     25       0.804878             Brain Tumor Classification
# 10           VGG     25       0.313588             Brain Tumor Classification
# ...

# %% [markdown]
# # Combining datasets 2 to dataset 6 make Combined results dataset

# %% [markdown]
# # Analysing on basis of test Accuracy scares of combined results of all datasets

# %%
# df = pd.concat([df, new_df], axis=0, ignore_index=True)

# %%
# df = pd.concat([df, new_df], axis=0, ignore_index=True)

# %%
dfr=pd.concat([dfr2,dfr3, dfr4,dfr5,dfr6 ], axis=0, ignore_index=True).sort_values('test_accuracy',ascending = False)
dfr
# Out:
#    activation_function  number_filters  pooling  epochs  test_accuracy  \
# 14                relu              64      max      25       0.981884
# 20                 elu              64  average      25       0.981884
# 25                relu              32      max      25       0.978261
# 27                relu             128      max      25       0.974638
# 18           LeakyReLU              64      max      25       0.974638
# ..                 ...             ...      ...     ...            ...
# 50                 elu              64  average      25       0.195000
# 51                gelu              64  average      25       0.187500
# 57                relu             128      max      25       0.182500
# 54                relu              16      max      25       0.177500
# 53           LeakyReLU              64  average      25       0.152500
#
#                  dataset
# 14      FaceMask Dataset
# 20      FaceMask Dataset
# 25      FaceMask Dataset
# ...

# %% [markdown]
# ## Average based result - analysis of Combined results dataset

# %%
dfr_p_avg = dfr.groupby('pooling').mean().sort_values('test_accuracy',ascending = False)
dfr_p_avg.head()
# Out:
#                          number_filters     epochs  test_accuracy
# pooling
# <built-in function max>       64.000000  25.000000       0.810951
# max                           60.622222  25.444444       0.663357
# average                       64.000000  25.000000       0.617042

# %%
dfr_act_avg = dfr.groupby('activation_function').mean().sort_values('test_accuracy',ascending = False)
dfr_act_avg.head()
# Out:
#                      number_filters     epochs  test_accuracy
# activation_function
# gelu                      57.846154  25.000000       0.687717
# LeakyReLU                 64.000000  25.000000       0.651346
# relu                      61.846154  25.769231       0.651127
# selu                      64.000000  25.000000       0.648485
# elu                       62.857143  25.000000       0.631575

# %%
dfr_filt_avg = dfr.groupby('number_filters').mean().sort_values('test_accuracy',ascending = False)
dfr_filt_avg.head()
# Out:
#                 epochs  test_accuracy
# number_filters
# 62                  30       0.688464
# 32                  25       0.676408
# 64                  25       0.658942
# 16                  25       0.605460
# 128                 25       0.576249

# %% [markdown]
# ### Based on average results of accuarcy for Combined results dataset 'gelu' , 'max-pooling' and '32' filters give best result accuarcy

# %% [markdown]
# ## Maximun (best) based result - analysis of Combined results dataset

# %%
dfr_p_max = dfr.groupby('pooling').max().sort_values('test_accuracy',ascending = False)
dfr_p_max.head()
# Out:
#                         activation_function  number_filters  epochs  \
# pooling
# average                                selu              64      25
# max                                    selu             128      30
# <built-in function max>                relu              64      25
#
#                          test_accuracy                                dataset
# pooling
# average                       0.981884                      cars_wagonr_swift
# max                           0.981884                      cars_wagonr_swift
# <built-in function max>       0.845323  Traffic Sign Dataset - Classification

# %%
dfr_act_max = dfr.groupby('activation_function').max().sort_values('test_accuracy',ascending = False)
dfr_act_max.head()
# Out:
#                      number_filters pooling  epochs  test_accuracy  \
# activation_function
# elu                             128     max      25       0.981884
# relu                            128     max      30       0.981884
# LeakyReLU                        64     max      25       0.974638
# gelu                             64     max      25       0.971014
# selu                             64     max      25       0.963768
#
#                                dataset
# activation_function
# elu                  cars_wagonr_swift
# relu                 cars_wagonr_swift
# LeakyReLU            cars_wagonr_swift
# gelu                 cars_wagonr_swift
# selu                 cars_wagonr_swift

# %%
dfr_filt_max = dfr.groupby('number_filters').max().sort_values('test_accuracy',ascending = False)
dfr_filt_max.head()
# Out:
#                activation_function pooling  epochs  test_accuracy  \
# number_filters
# 64                            selu     max      25       0.981884
# 32                            relu     max      25       0.978261
# 62                            relu     max      30       0.974638
# 128                           relu     max      25       0.974638
# 16                            relu     max      25       0.945652
#
#                           dataset
# number_filters
# 64              cars_wagonr_swift
# 32              cars_wagonr_swift
# 62              cars_wagonr_swift
# 128             cars_wagonr_swift
# 16              cars_wagonr_swift

# %% [markdown]
# ### Based on max results of accuracy for Combined results dataset 'elu' , 'max-pooling' and '64' filters give best result accuarcy

# %% [markdown]
# ### Final conculsion for Combined results dataset is the 'gelu' with 'max-pooling' and filters 32 or 64 will give better overall results

# %% [markdown]
# ## Imagenet winner models-Combined results dataset

# %%
df_imagenet
# Out:
#       model_name epochs  test_accuracy                                dataset
# 0         ResNet    100       0.964285         Grapevine Leaves Image Dataset
# 1   Inception_V3    100       0.802631         Grapevine Leaves Image Dataset
# 2         ResNet     25       0.956834  Traffic Sign Dataset - Classification
# 3   Inception_V3     25       0.928057  Traffic Sign Dataset - Classification
# 4            VGG     25       0.109112  Traffic Sign Dataset - Classification
# 5         ResNet     25       0.500000                       FaceMask Dataset
# 6   Inception_V3     25       0.996376                       FaceMask Dataset
# 7            VGG     25       0.500000                       FaceMask Dataset
# 8         ResNet     25       0.313588             Brain Tumor Classification
# 9   Inception_V3     25       0.804878             Brain Tumor Classification
# 10           VGG     25       0.313588             Brain Tumor Classification
# ...

# %% [markdown]
# ### Average results of Imagenet winner models for combined results datasets

# %%
df_imagenet_model_avg =df_imagenet.groupby('model_name').mean().sort_values('test_accuracy',ascending = False)

df_imagenet_model_avg
# Out:
#               test_accuracy
# model_name
# Inception_V3       0.812962
# ResNet             0.561894
# VGG                0.309873

# %% [markdown]
# ### Max results of Imagenet winner models for combined results datasets

# %%
df_imagenet_model_max =df_imagenet.groupby('model_name').max().sort_values('test_accuracy',ascending = False)

df_imagenet_model_max
# Out:
#               epochs  test_accuracy            dataset
# model_name
# Inception_V3     100       0.996376  cars_wagonr_swift
# ResNet           100       0.964285  cars_wagonr_swift
# VGG               25       0.516666  cars_wagonr_swift

# %% [markdown]
# #### This shows that Inception_V3 performed best on basis of both average nad max accuracy results for overall for all the datasest

# %% [markdown]
# # Analysis on basis of best accuracy results of individual datasets (Voting)

# %%
df_avg
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
# 5                ReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ### Out of 6 datasets on average accuracy
#
# ### 'ELu' performed best 2 times
#
# ### 'Max-pooling' best for all 6 datasets
#
# ### '64-filters' best for 5 datasets

# %%
df_max
# Out:
#   activation_function  pooling epochs number_filters  \
# 0                 elu      max    100             64
# 1                selu      max     25             64
# 2                 elu  average     25             64
# 3           LeakyReLU      max     25             64
# 4                ReLU      max     25             64
# 5                ReLU      max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ### Out of 6 datasets on max accuracy
#
# ### 'ELu' performed best 2 times
# ### 'ReLu' performed best 2 times
#
# ### 'Max-pooling' best for 5 datasets
#
# ### '64-filters' best for all 6 datasets

# %%
df_final
# Out:
#   activation_function pooling epochs number_filters  \
# 0                 elu     max    100            128
# 1                selu     max     25             64
# 2                gelu     max     25             32
# 3           LeakyReLU     max     25             64
# 4                 eLU     max     25             64
# 5                ReLU     max     25             64
#
#                                  dataset
# 0         Grapevine Leaves Image Dataset
# 1  Traffic Sign Dataset - Classification
# 2                       FaceMask Dataset
# 3             Brain Tumor Classification
# 4                   Watche Image Dataset
# 5                      cars_wagonr_swift

# %% [markdown]
# ### For concluded final results-Out of 6 datasets
#
# ### 'ELu' performed best 2 times
#
# ### 'Max-pooling' best for all 6 datasets
#
# ### '64-filters' best for all 4 datasets

# %% [markdown]
# # standard image processing techniques

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data will be put through following data processing:
#
# ##### 1) Making intial dataset with image paths, directories and names
#
# ##### 2) Reading images
#
# ##### 3) Converting images to array
#
# ##### 4) Reszizing image
#
# ##### 5) Forming final dataset with image array, image path, image name, image class etc
#
# ##### 6) Making train test datsest
#
# ##### 7) Normalizing the train , test data

# %% [markdown]
# ## Making a image preprocessing augmentation for CNN input

# %% [markdown]
# ### Data will be put through following image processing before being given to CNN:
#
# ##### 1) flips (horizaontal_vertical)
#
# ##### 2) Zooming
#
# ##### 3) Shifting (height and width)
#
# ##### 4) Rotation

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Number of filters observations
# #### One thing observed with all datasets was that varying number of filters was that as we increase the number of filters accuracy increases upto a point faterthat further increase in filter number decreases accuracy

# %% [markdown]
# #### The voting reults of each individual dataset is a better approach to chose form 'Elu' or 'gelu' (which was best average overall combined results dataset activation function) So we can chose 'elu'

# %% [markdown]
# ## Final conculsion
# ### Finally form above analysis we can conclude:
#
# ### 1) best activation function : 'Elu'
#
# ### 2) best pooling technique : 'Max-pooling
#
# ### 2) Filter number: '64'
